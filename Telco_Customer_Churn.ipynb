# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
df=pd.read_csv("C:\\Users\\kapur\\Downloads\\telco_churn_2\\Telco-Customer-Churn.csv")
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.tail()
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 7038          Yes               Yes             DSL            Yes  ...
# 7039          Yes               Yes     Fiber optic             No  ...
# 7040           No  No phone service             DSL            Yes  ...
# 7041          Yes               Yes     Fiber optic             No  ...
# 7042          Yes                No     Fiber optic            Yes  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %% [markdown]
# # Data Cleaning

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df["TotalCharges"]=df["TotalCharges"].str.strip()

# %%
df["TotalCharges"]=df["TotalCharges"].replace("",None)

# %%
df["TotalCharges"]=df["TotalCharges"].astype(float)

# %%
df.isnull().sum()
# Out:
# customerID           0
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %%
df["TotalCharges"].isnull().sum()
# Out:
# np.int64(11)

# %%
df=df.rename(columns={"customerID":"CustomerID","gender":"Gender","tenure":"Tenure"})
df
# Out:
#       CustomerID  Gender  SeniorCitizen Partner Dependents  Tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
df["TotalCharges"]=df["TotalCharges"].fillna(df["Tenure"]*df["MonthlyCharges"])

# %%
df["TotalCharges"].isnull().sum()
# Out:
# np.int64(0)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["CustomerID"].duplicated().sum()
# Out:
# np.int64(0)

# %%
df["SeniorCitizen"]=df["SeniorCitizen"].astype(str)

# %%
df["SeniorCitizen"]=df["SeniorCitizen"].replace({"0":"No","1":"Yes"})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   CustomerID        7043 non-null   object
#  1   Gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   object
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   Tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df
# Out:
#       CustomerID  Gender SeniorCitizen Partner Dependents  Tenure  \
# 0     7590-VHVEG  Female            No     Yes         No       1
# 1     5575-GNVDE    Male            No      No         No      34
# 2     3668-QPYBK    Male            No      No         No       2
# 3     7795-CFOCW    Male            No      No         No      45
# 4     9237-HQITU  Female            No      No         No       2
# ...          ...     ...           ...     ...        ...     ...
# 7038  6840-RESVB    Male            No     Yes        Yes      24
# 7039  2234-XADUH  Female            No     Yes        Yes      72
# 7040  4801-JZAZL  Female            No     Yes        Yes      11
# 7041  8361-LTMKD    Male           Yes     Yes         No       4
# 7042  3186-AJIEK    Male            No      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %% [markdown]
# # Exploratory Data Analysis EDA with Visualization

# %%
#Total Customers
df["CustomerID"].count()
# Out:
# np.int64(7043)

# %%
#Total Male and Females
df["Gender"].value_counts()
# Out:
# Gender
# Male      3555
# Female    3488
# Name: count, dtype: int64

# %%
#Total Senior Citizens
seniors=df["SeniorCitizen"].value_counts()
seniors
# Out:
# SeniorCitizen
# No     5901
# Yes    1142
# Name: count, dtype: int64

# %%
#Revenue by Total Charges
Revenue=df["TotalCharges"].sum()
Revenue
# Out:
# np.float64(16056168.7)

# %%
seniors.plot(kind='pie',autopct="%.0f%%")
plt.title("Senior Citizens")
plt.ylabel(" ")
plt.legend()
plt.show()

# %%
seniorsbygender=df.groupby("Gender")["SeniorCitizen"].value_counts()
seniorsbygender
# Out:
# Gender  SeniorCitizen
# Female  No               2920
#         Yes               568
# Male    No               2981
#         Yes               574
# Name: count, dtype: int64

# %%
seniorsbygender.plot(kind='pie',autopct="%0.2f%%")
plt.title("Total Senior Citizens by Gender")
plt.ylabel(" ")
plt.legend()
plt.show()

# %%
TotalCharges_by_Payment_Method=df.groupby("PaymentMethod")["TotalCharges"].sum()
TotalCharges_by_Payment_Method
# Out:
# PaymentMethod
# Bank transfer (automatic)    4748279.90
# Credit card (automatic)      4671593.35
# Electronic check             4944903.25
# Mailed check                 1691392.20
# Name: TotalCharges, dtype: float64

# %%
TotalCharges_by_Payment_Method.plot(kind='barh')
plt.title("Total Revenue by Payment Method")
plt.xlabel("Revenue in Lakhs")
plt.show()

# %%
Total_customers_by_Internetservice=df.groupby("InternetService")["CustomerID"].count()
Total_customers_by_Internetservice
# Out:
# InternetService
# DSL            2421
# Fiber optic    3096
# No             1526
# Name: CustomerID, dtype: int64

# %%
Total_customers_by_Internetservice.plot(kind='pie',autopct="%.0f%%",colors=['#1f77b4', '#aec7e8', '#17becf', '#9edae5', '#7f7f7f'])
plt.title("Total Customers by Internet Services")
plt.ylabel("")
plt.show()

# %% [raw]
# Customers are showing more interest with fiber optic Internet Service.

# %%
Paperlessbilling_by_internetservice=df.groupby("InternetService")["PaperlessBilling"].value_counts()
Paperlessbilling_by_internetservice
# Out:
# InternetService  PaperlessBilling
# DSL              Yes                 1330
#                  No                  1091
# Fiber optic      Yes                 2395
#                  No                   701
# No               No                  1080
#                  Yes                  446
# Name: count, dtype: int64

# %%
Paperlessbilling_by_internetservice.plot(kind='barh')
plt.title("PaperLess Billing by Internet Service")
plt.show()

# %% [raw]
# Customers are in more favour with paperlessbilling of fiber optic internet service

# %%
tech_supports_by_internetService=df.groupby("InternetService")["TechSupport"].value_counts()
tech_supports_by_internetService
# Out:
# InternetService  TechSupport
# DSL              No                     1243
#                  Yes                    1178
# Fiber optic      No                     2230
#                  Yes                     866
# No               No internet service    1526
# Name: count, dtype: int64

# %%
tech_supports_by_internetService.plot(kind='bar',color='brown')
plt.title("Tech Support Provided by Internet Service")
plt.ylabel("count")
plt.show()

# %%
churn_by_gender=df.groupby("Churn")["Gender"].value_counts()
churn_by_gender
# Out:
# Churn  Gender
# No     Male      2625
#        Female    2549
# Yes    Female     939
#        Male       930
# Name: count, dtype: int64

# %%
churn_by_gender.plot(kind='bar',color='blue')
plt.title("Churn Applied by Gender")
plt.ylabel("Count")
plt.show()

# %%
average_charges_by_churn=df.groupby("Churn")["MonthlyCharges"].mean()
average_charges_by_churn
# Out:
# Churn
# No     61.265124
# Yes    74.441332
# Name: MonthlyCharges, dtype: float64

# %%
churn_by_Contract=df.groupby("Contract")["Churn"].value_counts()
churn_by_Contract
# Out:
# Contract        Churn
# Month-to-month  No       2220
#                 Yes      1655
# One year        No       1307
#                 Yes       166
# Two year        No       1647
#                 Yes        48
# Name: count, dtype: int64

# %%
churn_by_Contract.plot(kind='line',marker='*')
plt.xticks(rotation=90)
plt.grid()
plt.ylabel("Count")
plt.title("Churn By Contract")
plt.show()

# %%
OnlineSecurity_by_contract=df.groupby("Contract")["OnlineSecurity"].value_counts()
OnlineSecurity_by_contract
# Out:
# Contract        OnlineSecurity
# Month-to-month  No                     2631
#                 Yes                     720
#                 No internet service     524
# One year        No                      557
#                 Yes                     552
#                 No internet service     364
# Two year        Yes                     747
#                 No internet service     638
#                 No                      310
# Name: count, dtype: int64

# %%
OnlineSecurity_by_contract.plot(kind="barh",color="red")
plt.title("Online Security Provided by Contract")
plt.xlabel("Count")
plt.show()

# %%
OnlineBackup_by_contract=df.groupby("Contract")["OnlineBackup"].value_counts()
OnlineBackup_by_contract
# Out:
# Contract        OnlineBackup
# Month-to-month  No                     2288
#                 Yes                    1063
#                 No internet service     524
# One year        Yes                     622
#                 No                      487
#                 No internet service     364
# Two year        Yes                     744
#                 No internet service     638
#                 No                      313
# Name: count, dtype: int64

# %%
OnlineBackup_by_contract.plot(kind='area',color='green')
plt.xticks(rotation=90)
plt.title("Onlline Backup Provided by Contract")
plt.ylabel("Count")
plt.show()

# %%
Techsupport_by_Contract=df.groupby("Contract")["TechSupport"].value_counts()
Techsupport_by_Contract
# Out:
# Contract        TechSupport
# Month-to-month  No                     2680
#                 Yes                     671
#                 No internet service     524
# One year        No                      557
#                 Yes                     552
#                 No internet service     364
# Two year        Yes                     821
#                 No internet service     638
#                 No                      236
# Name: count, dtype: int64

# %%
Techsupport_by_Contract.plot(kind='pie',autopct="%.0f%%")
plt.title("Tech support by contract")
plt.ylabel("")
plt.legend(loc="best", bbox_to_anchor=(1.2, 0.5))
plt.show()

# %%
StreamingTv_by_contract=df.groupby("Contract")["StreamingTV"].value_counts()
StreamingTv_by_contract
# Out:
# Contract        StreamingTV
# Month-to-month  No                     2053
#                 Yes                    1298
#                 No internet service     524
# One year        Yes                     652
#                 No                      457
#                 No internet service     364
# Two year        Yes                     757
#                 No internet service     638
#                 No                      300
# Name: count, dtype: int64

# %%
StreamingTv_by_contract.plot(kind='bar',color="magenta")
plt.title("Streaming TV by Contract")
plt.ylabel("Count")
plt.legend()
plt.show()

# %%
Streamingmovies_by_contract=df.groupby("Contract")["StreamingMovies"].value_counts()
Streamingmovies_by_contract
# Out:
# Contract        StreamingMovies
# Month-to-month  No                     2047
#                 Yes                    1304
#                 No internet service     524
# One year        Yes                     662
#                 No                      447
#                 No internet service     364
# Two year        Yes                     766
#                 No internet service     638
#                 No                      291
# Name: count, dtype: int64

# %%
Streamingmovies_by_contract.plot(kind='barh',color="orange")
plt.title("Streaming Movies by Contract")
plt.ylabel("Count")
plt.legend()
plt.show()

# %%
deviceprotection_by_contract=df.groupby("Contract")["DeviceProtection"].value_counts()
deviceprotection_by_contract
# Out:
# Contract        DeviceProtection
# Month-to-month  No                     2394
#                 Yes                     957
#                 No internet service     524
# One year        Yes                     646
#                 No                      463
#                 No internet service     364
# Two year        Yes                     819
#                 No internet service     638
#                 No                      238
# Name: count, dtype: int64

# %%
deviceprotection_by_contract.plot(kind='line',marker='.',markersize=8,color='black')
plt.title("Device Protection by Contract")
plt.xticks(rotation=90)
plt.ylabel("Count")
plt.grid()
plt.show()

# %% [raw]
# In this data most of cusotmer's have doesn't receive Techsupport, OnlineSecurity, OnlineBackup,StreamingTV,StreamingMovies,
# Device Protection who has contract of month-to-month so which of customer have month-to-month contract these customers
# can be leaving the Internet Service.

# %%
Phone_service_by_churn=df.groupby("Churn")["PhoneService"].value_counts()
Phone_service_by_churn
# Out:
# Churn  PhoneService
# No     Yes             4662
#        No               512
# Yes    Yes             1699
#        No               170
# Name: count, dtype: int64

# %%
partner_by_churn=df.groupby("Churn")["Partner"].value_counts()
partner_by_churn
# Out:
# Churn  Partner
# No     Yes        2733
#        No         2441
# Yes    No         1200
#        Yes         669
# Name: count, dtype: int64

# %%
dependents_by_churn=df.groupby("Churn")["Dependents"].value_counts()
dependents_by_churn
# Out:
# Churn  Dependents
# No     No            3390
#        Yes           1784
# Yes    No            1543
#        Yes            326
# Name: count, dtype: int64

# %%
average_tenure_by_churn=df.groupby("Churn")["Tenure"].mean()
average_tenure_by_churn
# Out:
# Churn
# No     37.569965
# Yes    17.979133
# Name: Tenure, dtype: float64

# %%
customers_by_multiplelines=df.groupby("MultipleLines")["CustomerID"].count()
customers_by_multiplelines
# Out:
# MultipleLines
# No                  3390
# No phone service     682
# Yes                 2971
# Name: CustomerID, dtype: int64

# %%
Multiple_lines_by_churn=df.groupby("Churn")["MultipleLines"].value_counts()
Multiple_lines_by_churn
# Out:
# Churn  MultipleLines
# No     No                  2541
#        Yes                 2121
#        No phone service     512
# Yes    Yes                  850
#        No                   849
#        No phone service     170
# Name: count, dtype: int64

# %%
maximum_tenure_customers=df[df["Tenure"]>70]
maximum_tenure_customers
# Out:
#       CustomerID  Gender SeniorCitizen Partner Dependents  Tenure  \
# 17    9959-WOFKT    Male            No      No        Yes      71
# 28    5248-YGIJN    Male            No     Yes         No      72
# 30    3841-NFECX  Female           Yes     Yes         No      71
# 35    6234-RAAPL  Female            No     Yes        Yes      72
# 59    5954-BDFSG  Female            No      No         No      72
# ...          ...     ...           ...     ...        ...     ...
# 6992  0218-QNVAS    Male            No     Yes        Yes      71
# 7007  2274-XUATA    Male           Yes     Yes         No      72
# 7022  7203-OYKCT    Male            No      No         No      72
# 7037  2569-WGERO  Female            No      No         No      72
# 7039  2234-XADUH  Female            No     Yes        Yes      72
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 17            Yes               Yes     Fiber optic                  Yes  ...
# ...

# %%
maximum_tenure_customers=df.groupby("Churn")["Tenure"].value_counts().sort_values(ascending=False)
maximum_tenure_customers
# Out:
# Churn  Tenure
# Yes    1         380
# No     72        356
#        1         233
#        71        164
# Yes    2         123
#                 ...
#        71          6
#        72          6
#        62          5
#        63          4
#        64          4
# Name: count, Length: 145, dtype: int64

# %%
maximum_tenure_customers.head(10).plot(kind='bar')
plt.title("Maximum Customers by Churn and Tenure")
plt.ylabel("Count")
plt.show()

# %% [raw]
# Most of the Customers Whoever have Tenure more than 70 months these customer are not leaving because most of these customers received
# OnlineSecurity, OnlineBackup, DeviceProtection, TechSupport, StreamingTV, StreamingMovies.

# %%
seniorcitizen_by_churn=df.groupby("Churn")["SeniorCitizen"].value_counts()
seniorcitizen_by_churn
# Out:
# Churn  SeniorCitizen
# No     No               4508
#        Yes               666
# Yes    No               1393
#        Yes               476
# Name: count, dtype: int64

# %%
onlinebackup_by_churn=df.groupby("Churn")["OnlineBackup"].value_counts()
onlinebackup_by_churn
# Out:
# Churn  OnlineBackup
# No     Yes                    1906
#        No                     1855
#        No internet service    1413
# Yes    No                     1233
#        Yes                     523
#        No internet service     113
# Name: count, dtype: int64

# %%
onlinebackup_by_churn.plot(kind='barh',color='gray')
plt.title("Online Backup by Churn")
plt.xlabel("Count")
plt.show()
